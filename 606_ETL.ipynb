# %%
#importing required base packages
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
#importing datasets

#FHFA HPI Master Dataset
url = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/HPI_master.csv'
hpi = pd.read_csv(url, error_bad_lines=False)

#Case-Schiller HPI
url2 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/CaseSchiller%20HPI'
hpi_cs = pd.read_csv(url2, error_bad_lines=False)

#Fed Fund Rate History
url3 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/FEDFUNDS.csv'
FedRates = pd.read_csv(url3, error_bad_lines=False)

#Zillow - For Sale Inventory
url4 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/For%20Sale%20Inventory%20(SFR)%20Metro%20and%20US.csv'
ForSaleInventory = pd.read_csv(url4, error_bad_lines=False)

#Zillow - Mean Days to Pending Sale
url5 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Mean%20Days%20to%20Pending%20(Metro%20Monthly).csv'
MeanDaysToSale = pd.read_csv(url5, error_bad_lines=False)

#Zillow - Median List Price Single Family Metro
url6 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Median%20List%20Price%20Single%20Family%20Metro.csv'
MedianListPrice = pd.read_csv(url6, error_bad_lines=False)

#Zillow - Median Sale Price Smoothed Seasonally Adjusted
url7 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Median_Sale_Price_Smooth_Seasonally_Adjusted_SingleFamily.csv'
MedianSalePriceSA = pd.read_csv(url7, error_bad_lines=False)

#Zillow - Mean Listing Price Cut Smoothed
url8 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Metro_mean_listings_price_cut_amt_uc_sfr_smoothed_month.csv'
MeanListingPriceCut = pd.read_csv(url8, error_bad_lines=False)

#Zillow - Mean Listing Price Cut Percent
url9 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Metro_mean_listings_price_cut_perc_uc_sfr_smoothed_month.csv'
MeanListingPriceCutPercent = pd.read_csv(url9, error_bad_lines=False)

#Zillow - Median Listing Price Cut
url10 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Metro_med_listings_price_cut_amt_uc_sfr_smoothed_month.csv'
MedianListingPriceCut = pd.read_csv(url10, error_bad_lines=False)

#Zillow - Median Listing Price Cut Percent
url11 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Metro_mean_listings_price_cut_perc_uc_sfr_smoothed_month.csv'
MedianListingPriceCutPercent = pd.read_csv(url11, error_bad_lines=False)

#Zillow - Newly Pending Listings
url12 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Newly%20Pending%20Listings_Metro.csv'
NewPendingListings = pd.read_csv(url12, error_bad_lines=False)

#Zillow - For Sale Inventory
url13 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/RAW%20For%20Sale%20Inventory%20(SFR)%20Metro%20and%20US.csv'
ForSaleInventory = pd.read_csv(url13, error_bad_lines=False)

#Zillow - Sale of Listings with Price Cut
url14 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Share%20of%20Listings%20with%20price%20cut_SingleFamily.csv'
PriceCutShare = pd.read_csv(url14, error_bad_lines=False)

#Zillow - County HPI
url15 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/ZHVI%20Single%20Family%20Home%20Time%20Series%20(COUNTY).csv'
ZillowCountyHPI = pd.read_csv(url15, error_bad_lines=False)

#Zillow - State HPI
url16 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/ZHVI%20Single%20Family%20Home%20Time%20Series%20(STATE).csv'
ZillowStateHPI = pd.read_csv(url16, error_bad_lines=False)

#Zillow - Single Family Home Time Series
url17 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/ZHVI%20Single%20Family%20Home%20Time%20Series.csv'
ZillowSFMTS = pd.read_csv(url17, error_bad_lines=False)

#Country Level Data - AR Model
url18 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/HPI_CountryLevel.csv'
ARTest = pd.read_csv(url18, error_bad_lines=False)

#Country Level Aggregate Metrics - For Correleogram
url19 = 'https://raw.githubusercontent.com/dancimiluca/DATA606/master/datasets/Country_Agg_Metrics.csv'
Country_Agg = pd.read_csv(url19, error_bad_lines=False)

# %%
ForSaleInventory
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# 5      394974         5                    Philadelphia, PA        Msa
# 6      394692         6                         Houston, TX        Msa
# 7      395209         7                      Washington, DC        Msa
# 8      394856         8           Miami-Fort Lauderdale, FL        Msa
# 9      394347         9                         Atlanta, GA        Msa
# 10     394404        10                          Boston, MA        Msa
# 11     395057        11                   San Francisco, CA        Msa
# 12     394532        12                         Detroit, MI        Msa
# 13     395025        13                       Riverside, CA        Msa
# 14     394976        14                         Phoenix, AZ        Msa
# 15     395078        15                         Seattle, WA        Msa
# 16     394865        16             Minneapolis-St Paul, MN        Msa
# 17     395056        17                       San Diego, CA        Msa
# 18     395121        18                       St. Louis, MO        Msa
# 19     395148        19                           Tampa, FL        Msa
# 20     394358        20                       Baltimore, MD        Msa
# 21     394530        21                          Denver, CO        Msa
# 22     394982        22                      Pittsburgh, PA        Msa
# 23     394998        23                        Portland, OR        Msa
# 24     394458        24                       Charlotte, NC        Msa
# 25     395045        25                      Sacramento, CA        Msa
# 26     395055        26                     San Antonio, TX        Msa
# 27     394943        27                         Orlando, FL        Msa
# 28     394466        28                      Cincinnati, OH        Msa
# 29     394475        29                       Cleveland, OH        Msa
# ..        ...       ...                                 ...        ...
# 91     394531        91                      Des Moines, IA        Msa
# 92     394711        92                         Jackson, MS        Msa
# 93     394352        94                         Augusta, GA        Msa
# 94     394666        96                      Harrisburg, PA        Msa
# 95     395006       100                           Provo, UT        Msa
# 96     394549       104                          Durham, NC        Msa
# 97     394995       119                  Port St. Lucie, FL        Msa
# 98     395183       124                         Vallejo, CA        Msa
# 99     394746       128                         Killeen, TX        Msa
# 100    395048       132                           Salem, OR        Msa
# 101    394927       149                           Ocala, FL        Msa
# 102    394602       159                    Fort Collins, CO        Msa
# 103    394405       162                         Boulder, CO        Msa
# 104    394471       172                     Clarksville, TN        Msa
# 105    394645       177                         Greeley, CO        Msa
# 106    394813       189               Macon-Bibb County, GA        Msa
# 107    394346       220                          Athens, GA        Msa
# 108    394623       229                     Gainesville, GA        Msa
# 109    395246       244                       Yuba City, CA        Msa
# 110    395009       251                     Punta Gorda, FL        Msa
# 111    395007       253                          Pueblo, CO        Msa
# 112    395094       331                         Sherman, TX        Msa
# 113    394546       343                            Dunn, NC        Msa
# 114    395166       383                         Truckee, CA        Msa
# 115    395153       399                    The Villages, FL        Msa
# 116    394586       504                       Faribault, MN        Msa
# 117    394309       527                       Albemarle, NC        Msa
# 118    394742       595                       Kerrville, TX        Msa
# 119    395091       641                     Shelbyville, TN        Msa
# 120    395230       672                      Wilmington, OH        Msa
#
# 23       8251.0      9300.0      9161.0      9351.0      9072.0
# 24      10280.0     11137.0     10058.0      9686.0      9291.0
# 25       5799.0      6746.0      6780.0      6373.0      6055.0
# 26      12220.0     13063.0     12834.0     12123.0     11507.0
# 27      11499.0     12591.0     12449.0     12036.0     11408.0
# 28       5569.0      6075.0      5993.0      5930.0      5821.0
# 29       7020.0      7451.0      7786.0      7802.0      7757.0
# ..          ...         ...         ...         ...         ...
# 91       3584.0      3743.0      3472.0      3357.0      3090.0
# 92       2217.0      2269.0      2106.0      2032.0      1899.0
# 93       2731.0      2692.0      2415.0      2499.0      2276.0
# 94       1286.0      1662.0      1811.0      1689.0      1578.0
# 95       2604.0      2826.0      2463.0      2202.0      1956.0
# 96       1911.0      2077.0      1992.0      1919.0      1812.0
# 97       4004.0      3986.0      3878.0      3609.0      3362.0
# 98        825.0       974.0       874.0       817.0       780.0
# 99       1941.0      2001.0      1779.0      1684.0         NaN
# 100      1724.0      1833.0      1824.0      1911.0      1873.0
# 101      2540.0      2608.0      2428.0      2271.0      2075.0
# 102      1362.0      1738.0      1754.0      1779.0      1638.0
# 103       878.0      1145.0      1199.0      1127.0      1002.0
# 104      2129.0      2262.0      2077.0      2085.0      2016.0
# 105      1313.0      1649.0      1587.0      1531.0      1497.0
# 106      1082.0      1070.0      1037.0       950.0         NaN
# 107       977.0      1016.0       989.0       956.0       940.0
# 108      1499.0      1558.0      1437.0      1366.0      1311.0
# 109       481.0       494.0       447.0       442.0       416.0
# 110      2418.0      2346.0      2223.0      2041.0      1845.0
# 111       704.0       804.0       776.0       807.0       780.0
# 112       874.0       932.0       905.0       900.0       861.0
# 113       686.0       689.0       628.0       601.0       542.0
# 114       640.0       807.0       780.0       725.0       651.0
# 115       603.0       679.0       681.0       730.0       754.0
# 116       238.0       273.0       263.0       279.0       266.0
# 117       205.0       203.0       192.0       181.0       170.0
# 118       347.0       361.0       385.0       384.0       360.0
# 119       240.0       251.0       229.0       224.0       215.0
# 120       105.0        95.0       109.0       106.0       110.0
#
# [121 rows x 40 columns]

# %%
#uncleansed data
hpi.plot(x='period')

# %%
#Historic Case Schiller HPI Trends
hpi_cs.plot()

# %%
hpi.describe
# Out:
# <bound method NDFrame.describe of              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# 5         traditional  purchase-only    monthly  USA or Census Division
# 6         traditional  purchase-only    monthly  USA or Census Division
# 7         traditional  purchase-only    monthly  USA or Census Division
# 8         traditional  purchase-only    monthly  USA or Census Division
# 9         traditional  purchase-only    monthly  USA or Census Division
# 10        traditional  purchase-only    monthly  USA or Census Division
# 11        traditional  purchase-only    monthly  USA or Census Division
# 12        traditional  purchase-only    monthly  USA or Census Division
# 13        traditional  purchase-only    monthly  USA or Census Division
# 14        traditional  purchase-only    monthly  USA or Census Division
# 15        traditional  purchase-only    monthly  USA or Census Division
# 16        traditional  purchase-only    monthly  USA or Census Division
# 17        traditional  purchase-only    monthly  USA or Census Division
# 18        traditional  purchase-only    monthly  USA or Census Division
# 19        traditional  purchase-only    monthly  USA or Census Division
# 20        traditional  purchase-only    monthly  USA or Census Division
# 21        traditional  purchase-only    monthly  USA or Census Division
# 22        traditional  purchase-only    monthly  USA or Census Division
# 23        traditional  purchase-only    monthly  USA or Census Division
# 24        traditional  purchase-only    monthly  USA or Census Division
# 25        traditional  purchase-only    monthly  USA or Census Division
# 26        traditional  purchase-only    monthly  USA or Census Division
# 27        traditional  purchase-only    monthly  USA or Census Division
# 28        traditional  purchase-only    monthly  USA or Census Division
# 29        traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 112954  developmental  purchase-only  quarterly             Puerto Rico
# 112955  developmental  purchase-only  quarterly             Puerto Rico
# 112956  developmental  purchase-only  quarterly             Puerto Rico
# 112957  developmental  purchase-only  quarterly             Puerto Rico
# 112958  developmental  purchase-only  quarterly             Puerto Rico
# 112959  developmental  purchase-only  quarterly             Puerto Rico
# 112960  developmental  purchase-only  quarterly             Puerto Rico
# 112961  developmental  purchase-only  quarterly             Puerto Rico
# 112962  developmental  purchase-only  quarterly             Puerto Rico
# 112963  developmental  purchase-only  quarterly             Puerto Rico
# 112964  developmental  purchase-only  quarterly             Puerto Rico
# 112965  developmental  purchase-only  quarterly             Puerto Rico
# 112966  developmental  purchase-only  quarterly             Puerto Rico
# 112967  developmental  purchase-only  quarterly             Puerto Rico
# 112968  developmental  purchase-only  quarterly             Puerto Rico
# 112969  developmental  purchase-only  quarterly             Puerto Rico
# 112970  developmental  purchase-only  quarterly             Puerto Rico
# 112971  developmental  purchase-only  quarterly             Puerto Rico
# 112972  developmental  purchase-only  quarterly             Puerto Rico
# 112973  developmental  purchase-only  quarterly             Puerto Rico
# 112974  developmental  purchase-only  quarterly             Puerto Rico
# 112975  developmental  purchase-only  quarterly             Puerto Rico
# 112976  developmental  purchase-only  quarterly             Puerto Rico
# 112977  developmental  purchase-only  quarterly             Puerto Rico
# 112978  developmental  purchase-only  quarterly             Puerto Rico
# 112979  developmental  purchase-only  quarterly             Puerto Rico
# 112980  developmental  purchase-only  quarterly             Puerto Rico
# 112981  developmental  purchase-only  quarterly             Puerto Rico
# 112982  developmental  purchase-only  quarterly             Puerto Rico
# 112983  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# 0       East North Central Division   DV_ENC  1991       1     100.00
# 1       East North Central Division   DV_ENC  1991       2     101.01
# 2       East North Central Division   DV_ENC  1991       3     101.36
# 3       East North Central Division   DV_ENC  1991       4     101.75
# 4       East North Central Division   DV_ENC  1991       5     102.39
# 5       East North Central Division   DV_ENC  1991       6     102.82
# 6       East North Central Division   DV_ENC  1991       7     103.01
# 7       East North Central Division   DV_ENC  1991       8     103.18
# 8       East North Central Division   DV_ENC  1991       9     102.88
# 9       East North Central Division   DV_ENC  1991      10     103.10
# 10      East North Central Division   DV_ENC  1991      11     104.02
# 11      East North Central Division   DV_ENC  1991      12     103.77
# 12      East North Central Division   DV_ENC  1992       1     103.94
# 13      East North Central Division   DV_ENC  1992       2     104.40
# 14      East North Central Division   DV_ENC  1992       3     105.58
# 15      East North Central Division   DV_ENC  1992       4     106.01
# 16      East North Central Division   DV_ENC  1992       5     106.58
# 17      East North Central Division   DV_ENC  1992       6     107.01
# 18      East North Central Division   DV_ENC  1992       7     107.19
# 19      East North Central Division   DV_ENC  1992       8     107.64
# 20      East North Central Division   DV_ENC  1992       9     107.64
# 21      East North Central Division   DV_ENC  1992      10     108.25
# 22      East North Central Division   DV_ENC  1992      11     108.53
# 23      East North Central Division   DV_ENC  1992      12     108.79
# 24      East North Central Division   DV_ENC  1993       1     108.54
# 25      East North Central Division   DV_ENC  1993       2     108.38
# 26      East North Central Division   DV_ENC  1993       3     109.30
# 27      East North Central Division   DV_ENC  1993       4     110.32
# 28      East North Central Division   DV_ENC  1993       5     110.93
# 29      East North Central Division   DV_ENC  1993       6     112.00
# ...                             ...      ...   ...     ...        ...
# 112954                  Puerto Rico       PR  2013       1     188.91
# 112955                  Puerto Rico       PR  2013       2     170.82
# 112956                  Puerto Rico       PR  2013       3     178.57
# 112957                  Puerto Rico       PR  2013       4     179.97
# 112958                  Puerto Rico       PR  2014       1     163.80
# 112959                  Puerto Rico       PR  2014       2     169.47
# 112960                  Puerto Rico       PR  2014       3     150.71
# 112961                  Puerto Rico       PR  2014       4     161.68
# 112962                  Puerto Rico       PR  2015       1     155.36
# 112963                  Puerto Rico       PR  2015       2     157.56
# 112964                  Puerto Rico       PR  2015       3     162.28
# 112965                  Puerto Rico       PR  2015       4     157.49
# 112966                  Puerto Rico       PR  2016       1     149.90
# 112967                  Puerto Rico       PR  2016       2     160.24
# 112968                  Puerto Rico       PR  2016       3     154.47
# 112969                  Puerto Rico       PR  2016       4     151.82
# 112970                  Puerto Rico       PR  2017       1     149.03
# 112971                  Puerto Rico       PR  2017       2     138.91
# 112972                  Puerto Rico       PR  2017       3     145.37
# 112973                  Puerto Rico       PR  2017       4     170.58
# 112974                  Puerto Rico       PR  2018       1     153.86
# 112975                  Puerto Rico       PR  2018       2     144.36
# 112976                  Puerto Rico       PR  2018       3     139.80
# 112977                  Puerto Rico       PR  2018       4     156.96
# 112978                  Puerto Rico       PR  2019       1     154.75
# 112979                  Puerto Rico       PR  2019       2     165.06
# 112980                  Puerto Rico       PR  2019       3     157.94
# 112981                  Puerto Rico       PR  2019       4     159.22
# 112982                  Puerto Rico       PR  2020       1     147.27
# 112983                  Puerto Rico       PR  2020       2     155.36
#
#         index_sa
# 0         100.00
# 1         101.08
# 2         100.98
# 3         101.04
# 4         101.45
# 5         101.56
# 6         101.90
# 7         102.10
# 8         102.06
# 9         102.41
# 10        103.36
# 11        103.47
# 12        103.96
# 13        104.47
# 14        105.20
# 15        105.27
# 16        105.60
# 17        105.68
# 18        106.03
# 19        106.50
# 20        106.77
# 21        107.50
# 22        107.86
# 23        108.49
# 24        108.60
# 25        108.43
# 26        108.95
# 27        109.55
# 28        109.91
# 29        110.60
# ...          ...
# 112954    194.45
# 112955    168.70
# 112956    179.42
# 112957    178.61
# 112958    168.45
# 112959    167.79
# 112960    152.12
# 112961    159.34
# 112962    159.57
# 112963    156.60
# 112964    164.64
# 112965    154.09
# 112966    153.55
# 112967    160.21
# 112968    157.15
# 112969    147.71
# 112970    152.54
# 112971    139.19
# 112972    148.29
# 112973    165.57
# 112974    157.22
# 112975    144.79
# 112976    142.92
# 112977    152.14
# 112978    158.18
# 112979    165.10
# 112980    162.01
# 112981    154.24
# 112982    150.59
# 112983    155.08
#
# [112984 rows x 10 columns]>

# %%
#importing auto regression model related libraries 
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import r2_score
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#checking AR Test
ARTest.head()
# Out:
#      date  FEDFUNDS  hpi_pct_chng
# 0  1/1/91      6.91      0.000000
# 1  2/1/91      6.25      0.450000
# 2  3/1/91      6.12      0.039821
# 3  4/1/91      5.91     -0.149269
# 4  5/1/91      5.78      0.059797

# %%
#formatting dataset to index by date
ARTest['date']=pd.to_datetime(ARTest['date'])
ARTest.set_index('date', inplace=True)

# %%
ARTest.head()
# Out:
#             FEDFUNDS  hpi_pct_chng
# date
# 1991-01-01      6.91      0.000000
# 1991-02-01      6.25      0.450000
# 1991-03-01      6.12      0.039821
# 1991-04-01      5.91     -0.149269
# 1991-05-01      5.78      0.059797

# %%
#quick graph of rate of change for HPI against Fed fund rate
ARTest.plot()

# %%
#Testing whether or not data is stationary using Dicky-Fuller Test
# Augmented Dickey-Fuller Test (ADF Test)/unit root test
#Source: https://towardsdatascience.com/multivariate-time-series-forecasting-653372b3db36
from statsmodels.tsa.stattools import adfuller
def adf_test(ts, signif=0.05):
    dftest = adfuller(ts, autolag='AIC')
    adf = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# Lags','# Observations'])
    for key,value in dftest[4].items():
       adf['Critical Value (%s)'%key] = value
    print (adf)
    
    p = adf['p-value']
    if p <= signif:
        print(f" Series is Stationary")
    else:
        print(f" Series is Non-Stationary")

# %%
#test model
ARmodel = VAR(ARTest)
ARmodel_fit = ARmodel.fit()
pred1 = ARmodel_fit.forecast(model_fit.y, steps=1)
print(pred)
print(pred)
print(model_fit)
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: RuntimeWarning: invalid value encountered in reduce
#   return getattr(obj, method)(*args, **kwds)
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:461: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   params = np.linalg.lstsq(z, y_sample)[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-fb5e9b19305d> in <module>()
#       2 ARmodel = VAR(ARTest)
#       3 ARmodel_fit = ARmodel.fit()
# ----> 4 pred1 = ARmodel_fit.forecast(model_fit.y, steps=1)
#       5 print(pred)
#       6 print(pred)
#
# ~/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py in forecast(self, y, steps)
#     677         Lutkepohl pp 37-38
#     678         """
# --> 679         return forecast(y, self.coefs, self.intercept, steps)
#     680
#     681     def mse(self, steps):
#
# ~/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py in forecast(y, coefs, intercept, steps)
#     209
#     210             # i=1 is coefs[0]
# --> 211             f = f + np.dot(coefs[i - 1], prior_y)
#     212         forcs[h - 1] = f
#     213
#
# ValueError: shapes (4,4) and (2,) not aligned: 4 (dim 1) != 2 (dim 0)

# %%
#apply adf test on the series
adf_test(ARTest["FEDFUNDS"])
adf_test(ARTest["hpi_pct_chng"])
# Out:
# Test Statistic           -2.481022
# p-value                   0.120160
# # Lags                    6.000000
# # Observations          347.000000
# Critical Value (1%)      -3.449337
# Critical Value (5%)      -2.869906
# Critical Value (10%)     -2.571227
# dtype: float64
#  Series is Non-Stationary
# Test Statistic           -2.462954
# p-value                   0.124750
# # Lags                   11.000000
# # Observations          342.000000
# Critical Value (1%)      -3.449616
# Critical Value (5%)      -2.870028
# Critical Value (10%)     -2.571292
# dtype: float64
#  Series is Non-Stationary

# %%
#data is non-stationary based on the given threshold, should probably be transformed...

# %%
pd.tools.plotting.lag_plot(ARTest['hpi_pct_chng'])
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.lag_plot' is deprecated, import 'pandas.plotting.lag_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
pd.tools.plotting.lag_plot(ARTest['FEDFUNDS'])
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.lag_plot' is deprecated, import 'pandas.plotting.lag_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
pd.tools.plotting.autocorrelation_plot(ARTest['hpi_pct_chng'])

#Appears to be pretty strong correlation in the first few periods
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
pd.tools.plotting.autocorrelation_plot(ARTest['FEDFUNDS'])
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   """Entry point for launching an IPython kernel.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
sd = seasonal_decompose(ARTest['hpi_pct_chng'], model='additive')
sd_check = sd.plot() 

#High Residuals during housing crisis around 2009
#Clear seasonality 
#Based on trend, this data looks mostly stationary... positive increase until ~2007, then decrease until 2009,... 
#...increase until 2014 then stabilizes

# %%
#Creating rolling 12 month variable, then a new variable subtracting rolling 12-month average from rate
ARTest['rolling_12M_HPI']=ARTest['hpi_pct_chng'].rolling(window = 12).mean()
ARTest['hpi_pct_chng_adj']=ARTest['hpi_pct_chng'] - ARTest['rolling_12M_HPI']

# %%
ARTest
# Out:
#             FEDFUNDS  hpi_pct_chng  rolling_12M_HPI  hpi_pct_chng_adj
# date
# 1991-01-01      6.91      0.000000              NaN               NaN
# 1991-02-01      6.25      0.450000              NaN               NaN
# 1991-03-01      6.12      0.039821              NaN               NaN
# 1991-04-01      5.91     -0.149269              NaN               NaN
# 1991-05-01      5.78      0.059797              NaN               NaN
# 1991-06-01      5.90      0.129482              NaN               NaN
# 1991-07-01      5.82      0.019895              NaN               NaN
# 1991-08-01      5.66     -0.179015              NaN               NaN
# 1991-09-01      5.45      0.249078              NaN               NaN
# 1991-10-01      5.21      0.298151              NaN               NaN
# 1991-11-01      4.81      0.535077              NaN               NaN
# 1991-12-01      4.43      0.384388         0.153117          0.231271
# 1992-01-01      4.03      0.412371         0.187481          0.224890
# 1992-02-01      4.06      0.694241         0.207835          0.486406
ARTest3.plot()

# %%
#Testing whether or not data is staionary 
adf_test(ARTest2["hpi_pct_chng_adj"])

#looks better...p value = 0.000105
# Out:
# Test Statistic           -4.649009
# p-value                   0.000105
# # Lags                   12.000000
# # Observations          330.000000
# Critical Value (1%)      -3.450322
# Critical Value (5%)      -2.870338
# Critical Value (10%)     -2.571458
# dtype: float64
#  Series is Stationary

# %%
sd = seasonal_decompose(ARTest2['hpi_pct_chng_adj'], model='additive')
sd_check = sd.plot() 

#adjusted home price data looks much better

# %%
ARTest2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-dc09df381bb8> in <module>()
# ----> 1 ARTest2.plot()
#
# NameError: name 'ARTest2' is not defined

# %%
#Test model
ARmodel2 = VAR(ARTest2)
ARmodel_fit2 = ARmodel2.fit()
ARforecast = ARmodel_fit2.forecast(ARmodel_fit2.y, steps=15)
print(ARforecast)
# Out:
# [[0.11677711 0.59915645 0.48887407 0.11028238]
#  [0.14197769 0.54806098 0.5000838  0.04797718]
#  [0.16583151 0.54495021 0.50909777 0.03585244]
#  [0.19015325 0.55031687 0.51761701 0.03269986]
#  [0.21525193 0.55709151 0.52594384 0.03114767]
#  [0.24116709 0.56400795 0.53413044 0.02987752]
#  [0.2678899  0.57083828 0.54218427 0.02865401]
#  [0.29540275 0.57754041 0.5501049  0.02743552]
#  [0.32368635 0.58410555 0.55789051 0.02621504]
#  [0.35272098 0.59053092 0.56553912 0.0249918 ]
#  [0.38248674 0.5968149  0.57304878 0.02376611]
#  [0.41296362 0.60295611 0.58041762 0.02253849]
#  [0.44413148 0.60895329 0.58764383 0.02130946]
#  [0.47597008 0.61480527 0.59472569 0.02007958]
#  [0.50845909 0.62051095 0.60166157 0.01884938]]
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:461: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   params = np.linalg.lstsq(z, y_sample)[0]

# %%
#ARTest3=ARTest2.drop(ARTest2.columns[[2,3]], axis = 1, inplace = True) 
ARTest3 = ARTest2.drop('hpi_pct_chng', axis=1)
#ARTest2.head()
ARTest2 = ARTest.dropna(axis=0, subset =['rolling_12M_HPI'])
ARTest3 = ARTest2.drop('hpi_pct_chng', axis=1)
ARTest3 = ARTest3.drop('rolling_12M_HPI', axis=1)
ARTest3.describe()
# Out:
#          FEDFUNDS  hpi_pct_chng_adj
# count  343.000000        343.000000
# mean     2.590554          0.004027
# std      2.156627          0.272628
# min      0.050000         -0.882486
# 25%      0.215000         -0.133794
# 50%      2.090000          0.014384
# 75%      4.885000          0.130890
# max      6.540000          1.678053

# %%
#splitting data for training vs testing
#create train/test datasets - 10 years of training data

AR_train1 = ARTest3[1:120]
AR_test1 = ARTest3[120:]

# %%
#Training the model on 10 years of testing
AR_train1.head()
# Out:
#             FEDFUNDS  hpi_pct_chng_adj
# date
# 1992-01-01      4.03          0.224890
# 1992-02-01      4.06          0.486406
# 1992-03-01      3.98         -0.355840
# 1992-04-01      3.73         -0.426102
# 1992-05-01      3.82         -0.133262

# %%
#Testing on present 
AR_test1.head()
# Out:
#             FEDFUNDS  hpi_pct_chng_adj
# date
# 2001-12-01      1.82          0.100351
# 2002-01-01      1.73          0.042079
# 2002-02-01      1.74          0.055202
# 2002-03-01      1.73          0.100729
# 2002-04-01      1.75         -0.006857

# %%
#10 Year Training Model 
AR10yr = VAR(AR_train1)
AR10yr_fit = AR10yr.fit()
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:461: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   params = np.linalg.lstsq(z, y_sample)[0]

# %%
#Looking at model coefficients
AR10yr_fit.params
# Out:
#                      FEDFUNDS  hpi_pct_chng_adj
# const               -0.057435         -0.048191
# L1.FEDFUNDS          1.008450          0.012828
# L1.hpi_pct_chng_adj  0.013709         -0.144353

# %%
ARforecast10yr = AR10yr_fit.forecast(AR10yr_fit.y, steps=15)
print(ARforecast10yr)
# Out:
# [[ 2.0470452   0.01210403]
#  [ 2.00707334 -0.02367858]
#  [ 1.96627319 -0.01902603]
#  [ 1.92519207 -0.02022103]
#  [ 1.88374745 -0.02057553]
#  [ 1.84194778 -0.02105601]
#  [ 1.79978833 -0.02152287]
#  [ 1.75726625 -0.02199631]
#  [ 1.71437838 -0.02247345]
#  [ 1.67112158 -0.02295475]
#  [ 1.62749268 -0.02344018]
#  [ 1.58348848 -0.02392979]
#  [ 1.53910574 -0.02442361]
#  [ 1.49434122 -0.02492167]
#  [ 1.44919163 -0.02542403]]

# %%
#TestCode
AR10yr_fit_test2 = AR10yr.fit(2)
AR10yr_fit_test12 = AR10yr.fit(12)
AR10yr_fit_test100 = AR10yr.fit(100)
# Out:
# /Users/danielcimiluca/Anaconda/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:461: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   params = np.linalg.lstsq(z, y_sample)[0]

# %%
AR10yr_fit_test2.plot()

# %%
AR10yr_fit_test12.plot()

# %%
AR10yr_fit_test100.plot()

# %%
AR10yr_fit_test12.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 28, Oct, 2020
# Time:                     23:01:51
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.81527
# Nobs:                     107.000    HQIC:                  -6.55793
# Log likelihood:           124.285    FPE:                0.000870307
# AIC:                     -7.06425    Det(Omega_mle):     0.000571863
# --------------------------------------------------------------------
# Results for equation FEDFUNDS
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.167516         0.091101            1.839           0.070
# L1.FEDFUNDS                  1.278189         0.106694           11.980           0.000
# L1.hpi_pct_chng_adj          0.057669         0.105580            0.546           0.586
# L2.FEDFUNDS                 -0.085491         0.177222           -0.482           0.631
# L2.hpi_pct_chng_adj         -0.000264         0.106849           -0.002           0.998
# L3.FEDFUNDS                 -0.162736         0.180536           -0.901           0.370
# L3.hpi_pct_chng_adj          0.058578         0.106839            0.548           0.585
# L4.FEDFUNDS                  0.109039         0.188537            0.578           0.565
# L4.hpi_pct_chng_adj          0.030604         0.105033            0.291           0.771
# L5.FEDFUNDS                 -0.143110         0.188256           -0.760           0.449
# L5.hpi_pct_chng_adj          0.110810         0.104298            1.062           0.291
# L6.FEDFUNDS                  0.113806         0.179046            0.636           0.527
# L6.hpi_pct_chng_adj          0.029889         0.106047            0.282           0.779
# L7.FEDFUNDS                 -0.147257         0.174644           -0.843           0.402
# L7.hpi_pct_chng_adj         -0.131332         0.107874           -1.217           0.227
# L8.FEDFUNDS                  0.021236         0.175339            0.121           0.904
# L8.hpi_pct_chng_adj          0.026427         0.107987            0.245           0.807
# L9.FEDFUNDS                  0.139226         0.177472            0.784           0.435
# L9.hpi_pct_chng_adj          0.015822         0.101871            0.155           0.877
# L10.FEDFUNDS                -0.240413         0.183491           -1.310           0.194
# L10.hpi_pct_chng_adj        -0.019314         0.098264           -0.197           0.845
# L11.FEDFUNDS                -0.165345         0.185807           -0.890           0.376
# L11.hpi_pct_chng_adj         0.094709         0.093398            1.014           0.314
# L12.FEDFUNDS                 0.247485         0.121916            2.030           0.046
# L12.hpi_pct_chng_adj        -0.007005         0.091622           -0.076           0.939
# =======================================================================================
#
# Results for equation hpi_pct_chng_adj
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.000540         0.092649            0.006           0.995
# L1.FEDFUNDS                 -0.192138         0.108507           -1.771           0.080
# L1.hpi_pct_chng_adj         -0.208833         0.107374           -1.945           0.055
# L2.FEDFUNDS                  0.385644         0.180233            2.140           0.035
# L2.hpi_pct_chng_adj         -0.045458         0.108665           -0.418           0.677
# L3.FEDFUNDS                 -0.242506         0.183603           -1.321           0.190
# L3.hpi_pct_chng_adj          0.081337         0.108655            0.749           0.456
# L4.FEDFUNDS                  0.108344         0.191741            0.565           0.574
# L4.hpi_pct_chng_adj         -0.075299         0.106818           -0.705           0.483
# L5.FEDFUNDS                 -0.099400         0.191455           -0.519           0.605
# L5.hpi_pct_chng_adj          0.150867         0.106070            1.422           0.159
# L6.FEDFUNDS                  0.121572         0.182088            0.668           0.506
# L6.hpi_pct_chng_adj          0.134009         0.107849            1.243           0.218
# L7.FEDFUNDS                 -0.076801         0.177611           -0.432           0.667
# L7.hpi_pct_chng_adj          0.094969         0.109707            0.866           0.389
# L8.FEDFUNDS                  0.105149         0.178319            0.590           0.557
# L8.hpi_pct_chng_adj          0.058624         0.109822            0.534           0.595
# L9.FEDFUNDS                 -0.190051         0.180488           -1.053           0.295
# L9.hpi_pct_chng_adj          0.070971         0.103602            0.685           0.495
# L10.FEDFUNDS                 0.211351         0.186609            1.133           0.261
# L10.hpi_pct_chng_adj        -0.036209         0.099933           -0.362           0.718
# L11.FEDFUNDS                -0.198723         0.188965           -1.052           0.296
# L11.hpi_pct_chng_adj        -0.050266         0.094985           -0.529           0.598
# L12.FEDFUNDS                 0.069933         0.123987            0.564           0.574
# L12.hpi_pct_chng_adj        -0.205523         0.093179           -2.206           0.030
# =======================================================================================
#
# Correlation matrix of residuals
#                     FEDFUNDS  hpi_pct_chng_adj
# FEDFUNDS            1.000000         -0.033259
# hpi_pct_chng_adj   -0.033259          1.000000

# %%
ARforecast10yr = AR10yr_fit.forecast(AR10yr_fit.y, steps=15)
print(ARforecast10yr)
# Out:
# [[ 2.0470452   0.01210403]
#  [ 2.00707334 -0.02367858]
#  [ 1.96627319 -0.01902603]
#  [ 1.92519207 -0.02022103]
#  [ 1.88374745 -0.02057553]
#  [ 1.84194778 -0.02105601]
#  [ 1.79978833 -0.02152287]
#  [ 1.75726625 -0.02199631]
#  [ 1.71437838 -0.02247345]
#  [ 1.67112158 -0.02295475]
#  [ 1.62749268 -0.02344018]
#  [ 1.58348848 -0.02392979]
#  [ 1.53910574 -0.02442361]
#  [ 1.49434122 -0.02492167]
#  [ 1.44919163 -0.02542403]]

# %%
#Running Test Model for remaining periods in forecast.... come back to this to plot against actuals
AR10yr_fit_test12.plot_forecast(220)

# %%
Country_Agg.head()
# Out:
#      date  FEDFUNDS  hpi_pct_chng  for_sale_inventory  mean_days_to_pending  \
# 0  1/1/91      6.91      0.000000                 NaN                   NaN
# 1  2/1/91      6.25      0.450000                 NaN                   NaN
# 2  3/1/91      6.12      0.039821                 NaN                   NaN
# 3  4/1/91      5.91     -0.149269                 NaN                   NaN
# 4  5/1/91      5.78      0.059797                 NaN                   NaN
#
#    median_list_price  median_sale_price  med_listing_price_cut_pct  \
# 0                NaN                NaN                        NaN
# 1                NaN                NaN                        NaN
# 2                NaN                NaN                        NaN
# 3                NaN                NaN                        NaN
# 4                NaN                NaN                        NaN
#
#    share_of_listing_w_pricecut
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
#Indexing by date
Country_Agg['date']=pd.to_datetime(Country_Agg['date'])
Country_Agg.set_index('date', inplace=True)

# %%
Country_Agg.head()
# Out:
#             FEDFUNDS  hpi_pct_chng  for_sale_inventory  mean_days_to_pending  \
# date
# 1991-01-01      6.91      0.000000                 NaN                   NaN
# 1991-02-01      6.25      0.450000                 NaN                   NaN
# 1991-03-01      6.12      0.039821                 NaN                   NaN
# 1991-04-01      5.91     -0.149269                 NaN                   NaN
# 1991-05-01      5.78      0.059797                 NaN                   NaN
#
#             median_list_price  median_sale_price  med_listing_price_cut_pct  \
# date
# 1991-01-01                NaN                NaN                        NaN
# 1991-02-01                NaN                NaN                        NaN
# 1991-03-01                NaN                NaN                        NaN
# 1991-04-01                NaN                NaN                        NaN
# 1991-05-01                NaN                NaN                        NaN
#
#             share_of_listing_w_pricecut
# date
# 1991-01-01                          NaN
# 1991-02-01                          NaN
# 1991-03-01                          NaN
# 1991-04-01                          NaN
# 1991-05-01                          NaN

# %%
#creating a diagonal correleogram
corr = Country_Agg.corr()

# %%
# Generate a mask for the upper half of correleogram
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

#Creating heatmap
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap)

# %%
chart1 = sns.heatmap(corr, mask=mask, cmap=cmap)

# %%
chart1.set_xticklabels(rotation=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2d016cb402f9> in <module>()
# ----> 1 chart1.set_xticklabels(rotation=30)
#
# TypeError: set_xticklabels() missing 1 required positional argument: 'labels'

# %%
chart1.set_xticklabels(chart1.get_xticklabels(),rotation=30)
# Out:
# [Text(0.5,0,'FEDFUNDS'),
#  Text(1.5,0,'hpi_pct_chng'),
#  Text(2.5,0,'for_sale_inventory'),
#  Text(3.5,0,'mean_days_to_pending'),
#  Text(4.5,0,'median_list_price'),
#  Text(5.5,0,'median_sale_price'),
#  Text(6.5,0,'med_listing_price_cut_pct'),
#  Text(7.5,0,'share_of_listing_w_pricecut')]

# %%
chart1
